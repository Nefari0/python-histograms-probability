# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
shift = 5
stretch = 2
n = 1000

pnts = np.random.randn(n)*stretch + shift
print('Mean is %g, Standard Deviation is %g' %(np.mean(pnts),np.std(pnts)))

fig,ax = plt.subplots(1,2,figsize=(6,4))

ax[0].plot(pnts,'s',alpha=.4)
ax[1].hist(pnts)
# Out:
# Mean is 5.05746, Standard Deviation is 1.98811
# (array([  2.,  19.,  68., 158., 250., 227., 164.,  75.,  27.,  10.]),
#  array([-1.44313836, -0.16267022,  1.11779791,  2.39826605,  3.67873419,
#          4.95920232,  6.23967046,  7.5201386 ,  8.80060673, 10.08107487,
#         11.361543  ]),
#  <BarContainer object of 10 artists>)
